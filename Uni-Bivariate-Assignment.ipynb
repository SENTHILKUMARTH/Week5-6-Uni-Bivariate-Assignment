# %%
import pandas as pd

# %%
dataset = pd.read_csv("Placement.csv")

# %%
#pd.set_option('display.max_rows', 1000)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#checking the null values

# %%
dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# #1.2 1)Replace the NaN values with correct value. And justify why you have chosen the same.
#
# ####Answer
#
# ##As per analysis student who are not placed in the company, there we are seeing the salary amount is NAN, so we are updating, NaN value to 0

# %%
dataset["salary"] = dataset["salary"].fillna(0)

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #1.3 2)How many of them are not placed?
#
# ####Answer
#
# ##As per analysis 67 students are not placed

# %%
NotPlaced = dataset[(dataset['status'] == 'Not Placed')]
NotPlaced
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# #1.4 3)Find the reason for non placement from the dataset?
#
# ####Answer
#
# ##As per analysis placement average pass mark is 62.579392, compare to the non placemnt average pass mark is 57.544030, that is the reason they have not placed

# %%
Placed = dataset[(dataset['status'] == 'Placed')]
Placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
NotPlaced.describe()
# Out:
#             sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# count   67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   110.477612  57.544030  58.395522  61.134179  69.587910  61.612836
# std     65.859667   8.394246   9.914090   6.365825  11.930687   5.705689
# min      4.000000  40.890000  37.000000  50.000000  50.000000  51.210000
# 25%     48.500000  52.000000  51.000000  57.000000  60.000000  58.480000
# 50%    107.000000  56.280000  60.330000  61.000000  67.000000  60.690000
# 75%    170.500000  63.000000  64.000000  65.000000  76.500000  65.405000
# max    215.000000  77.800000  82.000000  79.000000  97.000000  75.710000
#
#        salary
# count    67.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
Placed.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  148.000000  148.000000  148.000000  148.000000  148.000000  148.000000
# mean   106.878378   71.721486   69.926554   68.740541   73.238041   62.579392
# std     60.682502    8.715445    9.329268    6.518087   13.729333    5.884583
# min      1.000000   49.000000   50.830000   56.000000   50.000000   52.380000
# 25%     57.750000   65.000000   63.000000   65.000000   60.000000   57.772500
# 50%    108.500000   72.500000   68.000000   68.000000   72.000000   62.245000
# 75%    153.250000   78.125000   75.250000   72.422500   85.000000   66.760000
# max    214.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %% [markdown]
# #1.5 4)What kind of relation between salary and mba_p
#
# ####Answer
#
# ##salary and mba_p relationship between the 2 columns is 0.1398227389261557 and its a positivie correlation and 14% directly propational

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan, qual = quanQual(dataset)

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# #1.6 5)Which specialization is getting minimum salary?
#
# ####Answer
#
# ##Mkt&Fin specialization is getting minimum salary

# %%
dataset['specialisation'].min()
# Out:
# 'Mkt&Fin'

# %% [markdown]
# #1.7 6)How many of them getting above 500000 salary?
#
# ####Answer
#
# ##only 3 students are getting more than 500000 salary

# %%
dataset[dataset['salary'] >500000]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %% [markdown]
# #1.8 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)
#
# ####Answer:
#
# ##summary
#
# ##H0- There is a significant difference between etest_p and mba_p
#
# ##H1- There is no significant difference

# %%
import scipy.stats as stats

# %%
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# #1.9 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make
# #decision using Hypothesis Testing)
#
# ####Answer
#
# ##There is no similarity between Sci&Tech and Mkt&HR for Salary

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
ScienceTech = dataset[dataset['degree_t']=='Sci&Tech']['salary']
MktHR = dataset[dataset['specialisation']=='Mkt&HR']['salary']
#print(male)
ttest_ind(ScienceTech, MktHR)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %% [markdown]
# #1.10 9)Convert the normal distribution to standard normal distribution for
# #salary column

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\SENTHIL-KUMAR-T-H\AppData\Local\Temp\ipykernel_4576\2909774602.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# #1.11 10)What is the probability Density Function of the salary range from 700000 to 900000?
#
# ####Answer
#
# ##The area between range(700000,900000):0.0005973310593974901

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\SENTHIL-KUMAR-T-H\AppData\Local\Temp\ipykernel_4576\2842244316.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974901
# 0.0005973310593974901

# %% [markdown]
# #1.12 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)
#
# ####Answer
#
# ##There is no similarity between Sci&Tech of etest_p and Sci&Tech mark of mba_p

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
etest = dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mbap = dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(etest, mbap)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %% [markdown]
# #1.13 12)Which parameter is highly correlated with salary?
#
# ####Answer
#
# ##ss_p is highly correlated with salary 0.538090 and its a positivie correlation

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# ####1.14 13) plot any useful graph and explain it.
# #Standared Normal distribution

# %%
stdNBgraph(dataset["hsc_p"])
# Out:
# C:\Users\SENTHIL-KUMAR-T-H\AppData\Local\Temp\ipykernel_4576\2909774602.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
